# %% [markdown]
# <a href="https://colab.research.google.com/github/brunelboss/datos_ventas/blob/main/M2_AI3_PREDICCI%C3%93N_VENTAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importacion Librerías

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy import stats
import math
import scipy.stats as sp

from pandas._libs.hashtable import mode
from numpy.ma.extras import median
from numpy.core.fromnumeric import mean
import statistics as s
import math
from collections import Counter

from google.colab import data_table
data_table.enable_dataframe_formatter()

# !python --version
# Out:
# Python 3.7.12

# %%
df = pd.read_csv('https://github.com/brunelboss/datos_ventas/blob/f35fbbb71d2ff6f149e26e286659f038200675fb/datos_ventas.csv', sep = ';', header = 'infer', engine='python', index_col=0, decimal=',')
df
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/python_parser.py in _next_iter_line(self, row_num)
#     741             assert self.data is not None
# --> 742             return next(self.data)
#     743         except csv.Error as e:
#
# Error: ';' expected after '"'
#
# During handling of the above exception, another exception occurred:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-38-fa9145a7693a> in <module>()
# ----> 1 df = pd.read_csv('https://github.com/brunelboss/datos_ventas/blob/f35fbbb71d2ff6f149e26e286659f038200675fb/datos_ventas.csv', sep = ';', header = 'infer', engine='python', index_col=0, decimal=',')
#       2 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
plt.figure(figsize = (15,8))
plt.title('Probabilidad de Sobrevivir')
sns.set_theme(style="whitegrid")
sns.lineplot(data=df, x="Ventas", y="Inversion")

# %%
import seaborn as sns; sns.set_theme(color_codes=True)
ax = sns.regplot(x="Inversion", y="Ventas", data=df)

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
# utilizando la api de formula de statsmodels
est = smf.ols(formula='Ventas ~ Inversion', data=df).fit()
print(est.summary()) # Employed se estima en base a GNP.
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Ventas   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     384.9
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):           8.25e-21
# Time:                        01:44:46   Log-Likelihood:                -62.255
# No. Observations:                  38   AIC:                             128.5
# Df Residuals:                      36   BIC:                             131.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.8805      0.440      6.546      0.000       1.988       3.773
# ...
